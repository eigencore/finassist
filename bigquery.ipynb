# %%
from financial_assist.subagents.categorizer.tools import create_category
sql = await create_category(
    user_id="user_123",
    name="Travel Expenses",
    description="Expenses related to travel and transportation.",
    icon_reference="✈️"
)
print("Generated SQL Query: ", sql)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 2
#       1 from financial_assist.subagents.categorizer.tools import create_category
# ----> 2 sql = await create_category(
#       3     user_id="user_123",
#       4     name="Travel Expenses",
#       5     description="Expenses related to travel and transportation.",
#       6     icon_reference="✈️"
#       7 )
#       8 print("Generated SQL Query: ", sql)
#
# File ~/max/projects/finassist/financial_assist/subagents/categorizer/tools.py:178, in create_category(user_id, name, description, icon_reference)
#     175 if not client:
#     176     raise ValueError("BigQuery client is not available.")
# --> 178 sql_query = asyncio.run(
#     179     get_create_category_sql_query(
#     180         user_id=user_id,
#     181         name=name,
#     182         description=description,
# ...
